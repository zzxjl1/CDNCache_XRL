# %%
import random
import numpy as np
from torch.utils.data import Dataset, DataLoader
import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F


device = T.device("cuda:0" if T.cuda.is_available() else "cpu")

# %%
class DuelingDeepQNetwork(nn.Module):
    def __init__(self, alpha, state_dim, action_dim, fc1_dim, fc2_dim):
        super(DuelingDeepQNetwork, self).__init__()

        self.fc1 = nn.Linear(state_dim, fc1_dim)
        self.fc2 = nn.Linear(fc1_dim, fc2_dim)
        self.V = nn.Linear(fc2_dim, 1)
        self.A = nn.Linear(fc2_dim, action_dim)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.to(device)

    def forward(self, state):
        x = T.relu(self.fc1(state))
        x = T.relu(self.fc2(x))

        V = self.V(x)
        A = self.A(x)
        Q = V + A - T.mean(A, dim=-1, keepdim=True)

        return Q

    def save(self, file_path):
        T.save(self, file_path)

ACTIONS= ["PRESERVE", "DELETE"]

# %%
maintanance_agent = DuelingDeepQNetwork(alpha=1e-3,
                                  state_dim=11,
                                  action_dim=len(ACTIONS),
                                  fc1_dim=64,
                                  fc2_dim=32)


class MaintainanceDataset(Dataset):
    def __init__(self):
        self.data = []
        self.labels = []
        self.generate()

    def gen(self,func, num=100):
        for _ in range(num):
            obs, label = func()
            self.data.append(obs)
            self.labels.append(label)

    def generate(self):
        self.gen(self.cold_start)
    
    def get_loc(self):
        loc = {"L1": 0.8, "L2": 0.15, "L3": 0.05}
        T = random.random()
        if T < loc["L1"]:
            return "L1"
        elif T < loc["L1"] + loc["L2"]:
            return "L2"
        else:
            return "L3"

    def cold_start(self):
        loc = self.get_loc()
        obs = {
            "free_space_ratio":random.uniform(0.9, 1),
            "service_size_ratio":random.uniform(0, 0.3),
            "cached_in_L1": loc == "L1",
            "cached_in_L2": loc == "L2",
            "cached_in_L3": loc == "L3",
            "service_charm":random.randint(0, 10),
            "service_request_frequency":0,
            "ES_request_frequency":random.uniform(0, 10),
            "es_cache_miss_rate":random.uniform(0.8, 1),
            "least_freq_index":random.randint(0, 3),
            "is_ugent":0
        }
        return obs, "PRESERVE"

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        obs = list(self.data[index].values())
        label = self.labels[index]
        label_index = ACTIONS.index(label)
        one_hot = np.zeros(len(ACTIONS))
        one_hot[label_index] = 1
        return T.tensor(obs).float(), T.tensor(one_hot).float()

def train(network, epochs):
    loss_func = nn.CrossEntropyLoss()
    dataset = MaintainanceDataset()
    dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
    optimizer = network.optimizer
    for i in range(epochs):
        for data, labels in dataloader:
            optimizer.zero_grad()
            output = network(data)
            loss = loss_func(output, labels)
            loss.backward()
            optimizer.step()
            print(loss)

if __name__ == "__main__":
    train(maintanance_agent, 10)
    maintanance_agent.save("maintanance_agent.pt")
# Out:
# tensor(0.6447, grad_fn=<DivBackward1>)
# tensor(0.6326, grad_fn=<DivBackward1>)
# tensor(0.5896, grad_fn=<DivBackward1>)
# tensor(0.5646, grad_fn=<DivBackward1>)
# tensor(0.5424, grad_fn=<DivBackward1>)
# tensor(0.5015, grad_fn=<DivBackward1>)
# tensor(0.4852, grad_fn=<DivBackward1>)
# tensor(0.4707, grad_fn=<DivBackward1>)
# tensor(0.4339, grad_fn=<DivBackward1>)
# tensor(0.3999, grad_fn=<DivBackward1>)
# tensor(0.3709, grad_fn=<DivBackward1>)
# tensor(0.3373, grad_fn=<DivBackward1>)
# tensor(0.3190, grad_fn=<DivBackward1>)
# tensor(0.2838, grad_fn=<DivBackward1>)
# tensor(0.2895, grad_fn=<DivBackward1>)
# tensor(0.2586, grad_fn=<DivBackward1>)
# tensor(0.2258, grad_fn=<DivBackward1>)
# tensor(0.2027, grad_fn=<DivBackward1>)
# tensor(0.1945, grad_fn=<DivBackward1>)
# tensor(0.1475, grad_fn=<DivBackward1>)
# tensor(0.1316, grad_fn=<DivBackward1>)
# tensor(0.1374, grad_fn=<DivBackward1>)
# tensor(0.1276, grad_fn=<DivBackward1>)
# tensor(0.1229, grad_fn=<DivBackward1>)
# tensor(0.1174, grad_fn=<DivBackward1>)
# tensor(0.0920, grad_fn=<DivBackward1>)
# tensor(0.1093, grad_fn=<DivBackward1>)
# tensor(0.0799, grad_fn=<DivBackward1>)
# tensor(0.0606, grad_fn=<DivBackward1>)
# tensor(0.0704, grad_fn=<DivBackward1>)
# tensor(0.0520, grad_fn=<DivBackward1>)
# tensor(0.0996, grad_fn=<DivBackward1>)
# tensor(0.0582, grad_fn=<DivBackward1>)
# tensor(0.0501, grad_fn=<DivBackward1>)
# tensor(0.0363, grad_fn=<DivBackward1>)
# tensor(0.0457, grad_fn=<DivBackward1>)
# tensor(0.0380, grad_fn=<DivBackward1>)
# tensor(0.0446, grad_fn=<DivBackward1>)
# tensor(0.0247, grad_fn=<DivBackward1>)
# tensor(0.0206, grad_fn=<DivBackward1>)
# tensor(0.0203, grad_fn=<DivBackward1>)
# tensor(0.0275, grad_fn=<DivBackward1>)
# tensor(0.0204, grad_fn=<DivBackward1>)
# tensor(0.0176, grad_fn=<DivBackward1>)
# tensor(0.0105, grad_fn=<DivBackward1>)
# tensor(0.0188, grad_fn=<DivBackward1>)
# tensor(0.0154, grad_fn=<DivBackward1>)
# tensor(0.0099, grad_fn=<DivBackward1>)
# tensor(0.0112, grad_fn=<DivBackward1>)
# tensor(0.0109, grad_fn=<DivBackward1>)
# tensor(0.0128, grad_fn=<DivBackward1>)
# tensor(0.0122, grad_fn=<DivBackward1>)
# tensor(0.0067, grad_fn=<DivBackward1>)
# tensor(0.0162, grad_fn=<DivBackward1>)
# tensor(0.0179, grad_fn=<DivBackward1>)
# tensor(0.0047, grad_fn=<DivBackward1>)
# tensor(0.0131, grad_fn=<DivBackward1>)
# tensor(0.0051, grad_fn=<DivBackward1>)
# tensor(0.0095, grad_fn=<DivBackward1>)
# tensor(0.0114, grad_fn=<DivBackward1>)
# tensor(0.0058, grad_fn=<DivBackward1>)
# tensor(0.0123, grad_fn=<DivBackward1>)
# tensor(0.0037, grad_fn=<DivBackward1>)
# tensor(0.0108, grad_fn=<DivBackward1>)
# tensor(0.0079, grad_fn=<DivBackward1>)
# tensor(0.0146, grad_fn=<DivBackward1>)
# tensor(0.0052, grad_fn=<DivBackward1>)
# tensor(0.0043, grad_fn=<DivBackward1>)
# tensor(0.0092, grad_fn=<DivBackward1>)
# tensor(0.0062, grad_fn=<DivBackward1>)
# tensor(0.0050, grad_fn=<DivBackward1>)
# tensor(0.0058, grad_fn=<DivBackward1>)
# tensor(0.0066, grad_fn=<DivBackward1>)
# tensor(0.0084, grad_fn=<DivBackward1>)
# tensor(0.0036, grad_fn=<DivBackward1>)
# tensor(0.0035, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0038, grad_fn=<DivBackward1>)
# tensor(0.0054, grad_fn=<DivBackward1>)
# tensor(0.0072, grad_fn=<DivBackward1>)
# tensor(0.0018, grad_fn=<DivBackward1>)
# tensor(0.0033, grad_fn=<DivBackward1>)
# tensor(0.0026, grad_fn=<DivBackward1>)
# tensor(0.0031, grad_fn=<DivBackward1>)
# tensor(0.0041, grad_fn=<DivBackward1>)
# tensor(0.0030, grad_fn=<DivBackward1>)
# tensor(0.0036, grad_fn=<DivBackward1>)
# tensor(0.0021, grad_fn=<DivBackward1>)
# tensor(0.0023, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0035, grad_fn=<DivBackward1>)
# tensor(0.0027, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0033, grad_fn=<DivBackward1>)
# tensor(0.0021, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0057, grad_fn=<DivBackward1>)
# tensor(0.0022, grad_fn=<DivBackward1>)
# tensor(0.0045, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0036, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0021, grad_fn=<DivBackward1>)
# tensor(0.0027, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0018, grad_fn=<DivBackward1>)
# tensor(0.0047, grad_fn=<DivBackward1>)
# tensor(0.0035, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0034, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0040, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0028, grad_fn=<DivBackward1>)
# tensor(0.0025, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0028, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0022, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0028, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(8.0061e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(7.0403e-05, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.4229e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.3535e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.7522e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(7.6181e-05, grad_fn=<DivBackward1>)
# tensor(5.5647e-05, grad_fn=<DivBackward1>)
# tensor(7.2121e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(6.7354e-05, grad_fn=<DivBackward1>)
# tensor(5.7739e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(5.4423e-05, grad_fn=<DivBackward1>)
# tensor(4.3098e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(8.9223e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.8610e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(1.1287e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(4.2095e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(7.4184e-05, grad_fn=<DivBackward1>)
# tensor(9.0808e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.7848e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.9846e-05, grad_fn=<DivBackward1>)
# tensor(9.3854e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(2.0051e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(1.2673e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.2888e-05, grad_fn=<DivBackward1>)
# tensor(5.2425e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(8.9920e-05, grad_fn=<DivBackward1>)
# tensor(4.3818e-05, grad_fn=<DivBackward1>)
# tensor(5.4433e-05, grad_fn=<DivBackward1>)
# tensor(5.1727e-05, grad_fn=<DivBackward1>)
# tensor(8.9759e-05, grad_fn=<DivBackward1>)
# tensor(1.5589e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(8.7317e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(2.3634e-05, grad_fn=<DivBackward1>)
# tensor(4.0997e-05, grad_fn=<DivBackward1>)
# tensor(1.9948e-05, grad_fn=<DivBackward1>)
# tensor(6.7234e-05, grad_fn=<DivBackward1>)
# tensor(6.4824e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(3.2589e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(6.7375e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(9.1654e-05, grad_fn=<DivBackward1>)
# tensor(6.7343e-05, grad_fn=<DivBackward1>)
# tensor(7.5094e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(9.1254e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(9.8989e-05, grad_fn=<DivBackward1>)
# tensor(2.7593e-05, grad_fn=<DivBackward1>)
# tensor(7.9350e-05, grad_fn=<DivBackward1>)
# tensor(6.3477e-06, grad_fn=<DivBackward1>)
# tensor(3.4167e-05, grad_fn=<DivBackward1>)
# tensor(8.7023e-05, grad_fn=<DivBackward1>)
# tensor(1.3910e-05, grad_fn=<DivBackward1>)
# tensor(6.1206e-06, grad_fn=<DivBackward1>)
# tensor(8.1381e-05, grad_fn=<DivBackward1>)
# tensor(7.9816e-05, grad_fn=<DivBackward1>)
# tensor(2.5054e-05, grad_fn=<DivBackward1>)
# tensor(3.0332e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.5886e-05, grad_fn=<DivBackward1>)
# tensor(4.4420e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(5.1048e-05, grad_fn=<DivBackward1>)
# tensor(2.1937e-05, grad_fn=<DivBackward1>)
# tensor(2.8257e-05, grad_fn=<DivBackward1>)
# tensor(2.6514e-05, grad_fn=<DivBackward1>)
# tensor(9.3801e-05, grad_fn=<DivBackward1>)
# tensor(5.9190e-05, grad_fn=<DivBackward1>)
